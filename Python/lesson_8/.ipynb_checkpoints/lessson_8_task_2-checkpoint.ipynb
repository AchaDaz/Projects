# %%
import pandas as pd

# %% [markdown]
# ### Задание 3 Покемоны

# %%
pokemon_df = pd.read_csv('Pokemon.csv')

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.rename(columns=lambda x: x.replace('#', 'id')
                                     .replace('.', '')
                                     .replace(' ', '_')
                                     .lower(), inplace=True)

# %%
pokemon_df
# Out:
#       id                   name   type_1  type_2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#names_list = pokemon_df.columns.to_list()
#names_list

# %%
#for name in names_list:
#    name = name.lower().replace('#', 'id').replace('.', '').rea

# %%
#replaces = [('.', ''), (' ', '_')]
#names_series = names_series.str.replace('.', '')
#names_series = names_series.str.replace(' ', '_')
#
#

# %%
#names_series

# %%
#pokemon_df.columns = names_series

# %%
#pokemon_df

# %%
legends = pokemon_df.groupby('generation')['legendary'] \
    .value_counts().to_frame()

# %%
legends
# Out:
#                       legendary
# generation legendary
# 1          False            160
#            True               6
# 2          False            101
#            True               5
# 3          False            142
#            True              18
# 4          False            108
#            True              13
# 5          False            150
#            True              15
# 6          False             74
#            True               8

# %%
#

# %%
#names_series.str.replace('#', 'id')
#names_series.str.replace(r'.', r'')

# %% [markdown]
# ### Задание 4

# %%
legends.rename(columns={'legendary': 'legendary_count'}, inplace=True)

# %%
legends_unstacked = legends.unstack()

# %%
legends_unstacked
# Out:
#            legendary_count
# legendary            False True
# generation
# 1                      160    6
# 2                      101    5
# 3                      142   18
# 4                      108   13
# 5                      150   15
# 6                       74    8

# %% [markdown]
# ### Задание 5

# %%
pokemon_df.head()
# Out:
#    id                   name type_1  type_2  total  hp  attack  defense  \
# 0   1              Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                Ivysaur  Grass  Poison    405  60      62       63
# 2   3               Venusaur  Grass  Poison    525  80      82       83
# 3   3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4             Charmander   Fire     NaN    309  39      52       43
#
#    sp_atk  sp_def  speed  generation  legendary
# 0      65      65     45           1      False
# 1      80      80     60           1      False
# 2     100     100     80           1      False
# 3     122     120     80           1      False
# 4      60      50     65           1      False

# %%
pokemon_df.groupby(['generation', 'type_1'])['legendary'] \
    .value_counts() \
    .to_frame() \
    .unstack() \
    .loc[:, ('legendary', True)] \
    .to_frame() \
    .dropna() \
    .sort_values(('legendary', True), ascending=False).head()
# Out:
#                    legendary
#                         True
# generation type_1
# 3          Dragon        6.0
# 5          Dragon        5.0
# 3          Psychic       4.0
# 1          Psychic       3.0
# 4          Psychic       3.0

# %%
pokemon_df.groupby(['generation', 'type_1'])['legendary'] \
    .value_counts() \
    .to_frame() \
    .unstack() \
    .idxmax()
# Out:
#            legendary
# legendary  False         (1, Water)
#            True         (3, Dragon)
# dtype: object

# %% [markdown]
# ### Задание 6

# %%
avocado_agg = pd.DataFrame({'type' : ['conventional', 'organic'],
                            'AvgPrice_2015' : [1.077963, 1.673324],
                            'AvgPrice_2016' : [1.105595, 1.571684],
                            'AvgPrice_2017' : [1.294888, 1.735521],
                            'AvgPrice_2018' : [1.127886, 1.567176],
                            })
avocado_agg
# Out:
#            type  AvgPrice_2015  AvgPrice_2016  AvgPrice_2017  AvgPrice_2018
# 0  conventional       1.077963       1.105595       1.294888       1.127886
# 1       organic       1.673324       1.571684       1.735521       1.567176

# %%
avocado_agg_long = pd.wide_to_long(avocado_agg, ['AvgPrice'], i=['type'], j='year', sep='_')
avocado_agg_long
# Out:
#                    AvgPrice
# type         year
# conventional 2015  1.077963
# organic      2015  1.673324
# conventional 2016  1.105595
# organic      2016  1.571684
# conventional 2017  1.294888
# organic      2017  1.735521
# conventional 2018  1.127886
# organic      2018  1.567176

# %% [markdown]
# ### Задание 7

# %%
superheroes = pd.read_csv('superheroes_power_matrix.csv')

# %%
#superheroes_long = superheroes.melt(id_vars='Name') \
#    .query('value == True') \
#    .drop('value', axis=1) \
#    .rename(columns={'variable': 'superpower '})

# %%
superheroes_long = superheroes.melt(id_vars='Name',  var_name='superpower')
    
superheroes_powers = superheroes_long.query('value == True') \
    .groupby('Name') \
    .superpower \
    .apply(list).to_frame().reset_index()
