# %%
import pandas as pd

# %%
bookings = pd.read_csv('2_bookings.csv', sep=';')
bookings_head = bookings.head(7)

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings
# Out:
#                Hotel  Is Canceled  Lead Time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         Arrival Date Year Arrival Date Month  Arrival Date Week Number  \
# 0                    2015               July                        27
# ...

# %%
bookings.columns = bookings.columns.str.lower().str.replace(' ', '_')

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.query('is_canceled == 0') \
    .groupby('country') \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False).head()
# Out:
#          is_canceled
# country
# PRT            21071
# GBR             9676
# FRA             8481
# ESP             6391
# DEU             6069

# %%
bookings.query('country == "ITA"')
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 190     Resort Hotel            0         90        2015-07-06
# 336     Resort Hotel            0         88        2015-07-12
# 1466    Resort Hotel            0         34        2015-08-31
# 1530    Resort Hotel            0        154        2015-09-03
# 1533    Resort Hotel            0        154        2015-09-03
# ...              ...          ...        ...               ...
# 119289    City Hotel            0         25        2017-08-30
# 119324    City Hotel            0          8        2017-08-31
# 119339    City Hotel            0        110        2017-08-29
# 119362    City Hotel            0        198        2017-08-29
# 119364    City Hotel            0        212        2017-08-28
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 190                  2015               July                        28
# ...

# %%
bookings.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
bookings.groupby('hotel').agg({'stays_total_nights' : 'mean'}).round(decimals=2)
# Out:
#               stays_total_nights
# hotel
# City Hotel                  2.98
# Resort Hotel                4.32

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.query('reserved_room_type != assigned_room_type').shape
# Out:
# (14917, 21)

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.groupby(['arrival_date_year', 'arrival_date_month']).agg({'lead_time' : 'count'}).sort_values('lead_time', ascending=False)
# Out:
#                                       lead_time
# arrival_date_year arrival_date_month
# 2017              May                      6313
# 2016              October                  6203
# 2017              April                    5661
#                   June                     5647
# 2016              May                      5478
#                   April                    5428
#                   September                5394
# 2017              July                     5313
# 2016              June                     5292
# 2015              September                5114
# 2016              August                   5063
# 2017              March                    4970
# 2015              October                  4957
# 2017              August                   4925
# 2016              March                    4824
#                   July                     4572
#                   November                 4454
# 2017              February                 4177
# ...

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.query('is_canceled == 1' and 'hotel == "City Hotel"') \
    .groupby(['arrival_date_year', 'arrival_date_month'], as_index=False) \
    .agg({'reserved_room_type' : 'count'}) \
    .rename(columns={'reserved_room_type': 'bookings'}) \
    .sort_values(['arrival_date_year', 'bookings'], ascending=False)
# Out:
#     arrival_date_year arrival_date_month  bookings
# 25               2017                May      4556
# 23               2017               June      3971
# 18               2017              April      3919
# 22               2017               July      3559
# 24               2017              March      3412
# 19               2017             August      3125
# 20               2017           February      2594
# 21               2017            January      2372
# 16               2016            October      4219
# 12               2016               June      3923
# 17               2016          September      3871
# 14               2016                May      3676
# 6                2016              April      3561
# 7                2016             August      3378
# 11               2016               July      3131
# 15               2016           November      3122
# 13               2016              March      3046
# ...

# %%
bookings.groupby (['arrival_date_year', 'hotel', 'arrival_date_month'], as_index = False) \
    .agg ({"is_canceled" : 'count'})
#Так лучше не надо, сложная реализация
# Out:
#     arrival_date_year         hotel arrival_date_month  is_canceled
# 0                2015    City Hotel             August         2480
# 1                2015    City Hotel           December         1654
# 2                2015    City Hotel               July         1398
# 3                2015    City Hotel           November         1235
# 4                2015    City Hotel            October         3386
# 5                2015    City Hotel          September         3529
# 6                2015  Resort Hotel             August         1409
# 7                2015  Resort Hotel           December         1266
# 8                2015  Resort Hotel               July         1378
# 9                2015  Resort Hotel           November         1105
# 10               2015  Resort Hotel            October         1571
# 11               2015  Resort Hotel          September         1585
# 12               2016    City Hotel              April         3561
# ...

# %%
bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']

# %%
bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
bookings.groupby('hotel').agg({'total_kids': 'mean'}).round(2)
# Out:
#               total_kids
# hotel
# City Hotel          0.10
# Resort Hotel        0.14

# %%
has_kids = bookings['total_kids'] > 0
has_kids.shape
# Out:
# (119390,)

# %%
bookings[has_kids].query('is_canceled == 1').shape[0]/bookings[has_kids].shape[0]*100
# Out:
# 34.92284612087441

# %%
bookings[-has_kids].query('is_canceled == 1').shape[0]/bookings[-has_kids].shape[0]*100
# Out:
# 37.221283323338604
