# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('tables.xlsx')

# %%
file = open('tables.xlsx', encoding='ISO-8859-1')

# %%
lines = file.readlines()

# %%
df
# Out:
#    Unnamed: 0  company41  company51  company50  company76  company47  \
# 0         NaN        580        198        968        220        788
# 1         NaN        786        271         69        566        NaN
# 2         NaN        578        NaN        526         74        984
# 3         NaN        614        NaN        589        575         85
# 4         NaN         44        849        992        155        527
# 5         NaN        859        966        918        312        NaN
# 6         NaN        225        486         20        367        339
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN  company41  company51  company50  company76  company47
# 10        NaN        110        828        253        NaN        818
# 11        NaN        958        266        105        870        384
# 12        NaN        843         19        467        784        885
# ...

# %%
df_1 = df.loc[9:17]
df_2 = df.loc[18:21]
df_3 = df.loc[22:27]
df_4 = df.loc[28:37]
df_5 = df.loc[38:43]

# %%
df_1.columns = df_1.iloc[0]
df_2.columns = df_2.iloc[0]
df_3.columns = df_3.iloc[0]
df_4.columns = df_4.iloc[0]
df_5.columns = df_5.iloc[0]

# %%
df_1 = df_1.reset_index(drop=True)
df_2 = df_2.reset_index(drop=True)
df_3 = df_3.reset_index(drop=True)
df_4 = df_4.reset_index(drop=True)
df_5 = df_5.reset_index(drop=True)

# %%
df_1 = df_1.drop(0)
df_2 = df_2.drop(0)
df_3 = df_3.drop(0)
df_4 = df_4.drop(0)
df_5 = df_5.drop(0)

# %%
df = df.drop(df.iloc[9:44].index)

# %%
df_concat = pd.concat([df, df_1, df_2, df_3, df_4, df_5], axis=1)

# %%
del df_concat['Unnamed: 0']

# %%
df_concat
# Out:
#   company41 company51 company50 company76 company47 company27 company48  NaN  \
# 0       580       198       968       220       788       554       479  NaN
# 1       786       271        69       566       NaN       193       636  NaN
# 2       578       NaN       526        74       984       581       951  NaN
# 3       614       NaN       589       575        85       122       454  NaN
# 4        44       849       992       155       527        33       NaN  NaN
# 5       859       966       918       312       NaN       404       407  NaN
# 6       225       486        20       367       339       481       252  NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN  NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN  NaN
#
#   company41 company51  ... company27 company48  NaN company41 company51  \
# ...

# %%
df_concat.dropna(axis='columns',how='all', inplace=True)

# %%
df_concat
# Out:
#   company41 company51 company50 company76 company47 company27 company48  \
# 0       580       198       968       220       788       554       479
# 1       786       271        69       566       NaN       193       636
# 2       578       NaN       526        74       984       581       951
# 3       614       NaN       589       575        85       122       454
# 4        44       849       992       155       527        33       NaN
# 5       859       966       918       312       NaN       404       407
# 6       225       486        20       367       339       481       252
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#   company41 company51 company50  ... company47 company27 company48 company41  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
df_concat.dropna(axis='rows',how='all', inplace=True)

# %%
df_concat
# Out:
#   company41 company51 company50 company76 company47 company27 company48  \
# 0       580       198       968       220       788       554       479
# 1       786       271        69       566       NaN       193       636
# 2       578       NaN       526        74       984       581       951
# 3       614       NaN       589       575        85       122       454
# 4        44       849       992       155       527        33       NaN
# 5       859       966       918       312       NaN       404       407
# 6       225       486        20       367       339       481       252
#
#   company41 company51 company50  ... company47 company27 company48 company41  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1       110       828       253  ...       965       750       720       438
# 2       958       266       105  ...       729       924       586       427
# 3       843        19       467  ...       NaN       665        85       887
# ...

# %%
df_concat['company41'].sum()
# Out:
# company41    3686
# company41    2663
# company41    1029
# company41    1687
# company41    3373
# company41    2480
# dtype: object

# %%
df_concat.columns
# Out:
# Index(['company41', 'company51', 'company50', 'company76', 'company47',
#        'company27', 'company48', 'company41', 'company51', 'company50',
#        'company76', 'company47', 'company27', 'company48', 'company41',
#        'company51', 'company50', 'company76', 'company47', 'company27',
#        'company48', 'company41', 'company51', 'company50', 'company76',
#        'company47', 'company27', 'company48', 'company41', 'company51',
#        'company50', 'company76', 'company47', 'company27', 'company48',
#        'company41', 'company51', 'company50', 'company76', 'company47',
#        'company27', 'company48'],
#       dtype='object')

# %%
df_new = df.loc[22:27]

# %%
df_new
# Out:
#    Unnamed: 0  company41  company51  company50  company76  company47  \
# 22  company41  company51  company50  company76  company47  company27
# 23         16        151        217        144        993        633
# 24        819         43        660        NaN        312        936
# 25        227        783        589        NaN        516        782
# 26        625        858        228        NaN        832        197
# 27        NaN        NaN        NaN        NaN        NaN        NaN
#
#     company27 company48
# 22  company48       NaN
# 23        747       NaN
# 24        983       NaN
# 25        736       NaN
# 26        116       NaN
# 27        NaN       NaN

# %%
df_new.columns = df_new.iloc[0]

# %%
df_new = df_new.reset_index(drop=True)

# %%
df_new.drop([0], axis=0, inplace=True)

# %%
df_new.dropna(axis='columns',how='all', inplace=True)

# %%
df_new.drop([5], axis=0, inplace=True)

# %%
df_new
# Out:
# 22 company41 company51 company50 company76 company47 company27 company48
# 1         16       151       217       144       993       633       747
# 2        819        43       660       NaN       312       936       983
# 3        227       783       589       NaN       516       782       736
# 4        625       858       228       NaN       832       197       116

# %%
df = df.drop(df.iloc[22:27].index)

# %%
df_new = df_new.reset_index()

# %%
df_new
# Out:
#    level_0  index Unnamed: 0 company41 company51 company50 company76  \
# 1        1     23         16       151       217       144       993
# 2        2     24        819        43       660       NaN       312
# 3        3     25        227       783       589       NaN       516
# 4        4     26        625       858       228       NaN       832
# 5        5     27        NaN       NaN       NaN       NaN       NaN
#
#   company47 company27 company48
# 1       633       747       NaN
# 2       936       983       NaN
# 3       782       736       NaN
# 4       197       116       NaN
# 5       NaN       NaN       NaN

# %%
df_new.drop(['level_0', 'index'], axis=1, inplace=True)

# %%
df_new.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_new
# Out:
# 22 company41 company51 company50 company76 company47 company27 company48
# 1         16       151       217       144       993       633       747
# 2        819        43       660       NaN       312       936       983
# 3        227       783       589       NaN       516       782       736
# 4        625       858       228       NaN       832       197       116

# %%
del df['Unnamed: 0']

# %%
df.drop([9, 18, 28, 38], axis=0, inplace=True)

# %%
df = df.drop(df.loc[22:27].index)

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#    company41 company51 company50 company76 company47 company27 company48
# 0        580       198       968       220       788       554       479
# 1        786       271        69       566       NaN       193       636
# 2        578       NaN       526        74       984       581       951
# 3        614       NaN       589       575        85       122       454
# 4         44       849       992       155       527        33       NaN
# 5        859       966       918       312       NaN       404       407
# 6        225       486        20       367       339       481       252
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 10       110       828       253       NaN       818        15       752
# 11       958       266       105       870       384       NaN       NaN
# 12       843        19       467       784       885       870       177
# ...

# %%
df_concat_last = pd.concat([df, df_new], axis=0)

# %%
df_concat_last
# Out:
#    company41 company51 company50 company76 company47 company27 company48
# 0        580       198       968       220       788       554       479
# 1        786       271        69       566       NaN       193       636
# 2        578       NaN       526        74       984       581       951
# 3        614       NaN       589       575        85       122       454
# 4         44       849       992       155       527        33       NaN
# 5        859       966       918       312       NaN       404       407
# 6        225       486        20       367       339       481       252
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 10       110       828       253       NaN       818        15       752
# 11       958       266       105       870       384       NaN       NaN
# 12       843        19       467       784       885       870       177
# ...

# %%
df_concat_last.dropna(axis='rows',how='all', inplace=True)

# %%
df_concat_last.reset_index(drop=True)
# Out:
#    company41 company51 company50 company76 company47 company27 company48
# 0        580       198       968       220       788       554       479
# 1        786       271        69       566       NaN       193       636
# 2        578       NaN       526        74       984       581       951
# 3        614       NaN       589       575        85       122       454
# 4         44       849       992       155       527        33       NaN
# 5        859       966       918       312       NaN       404       407
# 6        225       486        20       367       339       481       252
# 7        110       828       253       NaN       818        15       752
# 8        958       266       105       870       384       NaN       NaN
# 9        843        19       467       784       885       870       177
# 10       143       583       NaN       NaN       716       671       907
# 11       499       469       666       887       142       487        33
# ...

# %%
df_concat_last['company41'].sum()
# Out:
# 14918
